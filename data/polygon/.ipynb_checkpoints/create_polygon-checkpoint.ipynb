# %%
# %pip install folium pandas shapely geopandas
# Out:
# Collecting folium
#   Downloading folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pandas in c:\users\rlatj\anaconda3\lib\site-packages (2.2.3)
# Collecting shapely
#   Downloading shapely-2.1.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Collecting geopandas
#   Downloading geopandas-1.1.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\rlatj\anaconda3\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\rlatj\anaconda3\lib\site-packages (from folium) (2.1.3)
# Requirement already satisfied: requests in c:\users\rlatj\anaconda3\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\rlatj\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rlatj\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rlatj\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rlatj\anaconda3\lib\site-packages (from pandas) (2025.2)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.11.1-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: packaging in c:\users\rlatj\anaconda3\lib\site-packages (from geopandas) (24.2)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.2-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rlatj\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: certifi in c:\users\rlatj\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.4.26)
# Requirement already satisfied: six>=1.5 in c:\users\rlatj\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rlatj\anaconda3\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rlatj\anaconda3\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rlatj\anaconda3\lib\site-packages (from requests->folium) (2.3.0)
# Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Downloading shapely-2.1.1-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------ --------------- 1.0/1.7 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.9 MB/s eta 0:00:00
# Downloading geopandas-1.1.1-py3-none-any.whl (338 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading pyogrio-0.11.1-cp313-cp313-win_amd64.whl (19.2 MB)
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/19.2 MB 5.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 2.1/19.2 MB 5.6 MB/s eta 0:00:04
#    ------- -------------------------------- 3.4/19.2 MB 5.7 MB/s eta 0:00:03
#    --------- ------------------------------ 4.7/19.2 MB 5.8 MB/s eta 0:00:03
#    ------------ --------------------------- 6.0/19.2 MB 5.9 MB/s eta 0:00:03
#    -------------- ------------------------- 7.1/19.2 MB 5.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 8.4/19.2 MB 5.9 MB/s eta 0:00:02
#    ------------------- -------------------- 9.4/19.2 MB 5.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 10.7/19.2 MB 5.9 MB/s eta 0:00:02
#    ------------------------- -------------- 12.1/19.2 MB 5.9 MB/s eta 0:00:02
#    --------------------------- ------------ 13.4/19.2 MB 5.9 MB/s eta 0:00:01
#    ------------------------------ --------- 14.7/19.2 MB 6.0 MB/s eta 0:00:01
#    -------------------------------- ------- 15.7/19.2 MB 6.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.0/19.2 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------- -- 18.1/19.2 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 19.2/19.2 MB 5.9 MB/s eta 0:00:00
# Downloading pyproj-3.7.2-cp313-cp313-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.3 MB 5.7 MB/s eta 0:00:01
#    -------------- ------------------------- 2.4/6.3 MB 6.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.3 MB 6.1 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.3 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.3 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 6.0 MB/s eta 0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, branca, geopandas, folium
#
#    ---------------------------------------- 0/6 [shapely]
#    ---------------------------------------- 0/6 [shapely]
#    ---------------------------------------- 0/6 [shapely]
#    ---------------------------------------- 0/6 [shapely]
#    ---------------------------------------- 0/6 [shapely]
#    ---------------------------------------- 0/6 [shapely]
#    ---------------------------------------- 0/6 [shapely]
#    ---------------------------------------- 0/6 [shapely]
#    ------ --------------------------------- 1/6 [pyproj]
#    ------ --------------------------------- 1/6 [pyproj]
#    ------------- -------------------------- 2/6 [pyogrio]
#    ------------- -------------------------- 2/6 [pyogrio]
#    ------------- -------------------------- 2/6 [pyogrio]
#    ------------- -------------------------- 2/6 [pyogrio]
#    ------------- -------------------------- 2/6 [pyogrio]
#    ------------- -------------------------- 2/6 [pyogrio]
#    ------------- -------------------------- 2/6 [pyogrio]
#    -------------------------- ------------- 4/6 [geopandas]
#    -------------------------- ------------- 4/6 [geopandas]
#    -------------------------- ------------- 4/6 [geopandas]
#    -------------------------- ------------- 4/6 [geopandas]
#    -------------------------- ------------- 4/6 [geopandas]
#    --------------------------------- ------ 5/6 [folium]
#    --------------------------------- ------ 5/6 [folium]
#    --------------------------------- ------ 5/6 [folium]
#    ---------------------------------------- 6/6 [folium]
#
# Successfully installed branca-0.8.1 folium-0.20.0 geopandas-1.1.1 pyogrio-0.11.1 pyproj-3.7.2 shapely-2.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
import pandas as pd
from shapely.geometry import Point, shape
import json

# %% [markdown]
# ### **selected_area.geojson 파일 이동(polygon export한 뒤에 실행)**

# %%
# 다운로드 된 selected_area.geojson 파일 위치 변경
import os
import shutil

# 현재 노트북이 실행 중인 폴더 (루트 폴더)
root_dir = os.getcwd()

# 브라우저 기본 다운로드 폴더
download_dir = os.path.expanduser("~/Downloads")

# 원본 파일 경로
src_file = os.path.join(download_dir, "selected_area.geojson")

# 이동할 경로 (루트 폴더 안)
dst_file = os.path.join(root_dir, "selected_area.geojson")

# 파일이 존재할 때만 이동
if os.path.exists(src_file):
    shutil.move(src_file, dst_file)
    print(f"✅ 파일 이동 완료: {dst_file}")
else:
    print("❌ 다운로드 폴더에서 selected_area.geojson을 찾을 수 없습니다.")
# Out:
# ✅ 파일 이동 완료: C:\Users\rlatj\Programming_Workspace\Hanyang_Programming\Soomgil\data\polygon\selected_area.geojson

# %% [markdown]
# ### **polygon 저장(target_tag 설정 필수)**

# %%
target_tag = 'park' # park, river, mountain  *********************실행 전 확인************************

# properties의 type 설정
with open("selected_area.geojson") as f:
    geojson_data = json.load(f)

# # XXX_area.geojson 파일 수정 또는 확인 시 실행
# with open("polygon_data/park_area.geojson") as f:
#     geojson_data = json.load(f)

for i, feature in enumerate(geojson_data["features"]):
    feature["properties"]["type"] = target_tag

# %% [markdown]
# ### **지표에 polygon 표시(확인용)**

# %%
nodes_gdf = pd.read_csv("nodes.csv") # *********************실행 전 확인************************

center_lat = nodes_gdf["lat"].mean()
center_lon = nodes_gdf["lon"].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=14)

# Esri.WorldImagery 스타일 적용
folium.TileLayer(
    tiles='https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Tiles © Esri — Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, '
         'Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community',
    name='Esri.WorldImagery',
    overlay=False,
    control=True
).add_to(m)

# polygon 표시
folium.GeoJson(
    geojson_data,
    name="polygons",
    tooltip=folium.GeoJsonTooltip(fields=["type"], aliases=["Type"])
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b27725f37410017bf6fdff13bc60ac21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b27725f37410017bf6fdff13bc60ac21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b27725f37410017bf6fdff13bc60ac21 = L.map(
#                 &quot;map_b27725f37410017bf6fdff13bc60ac21&quot;,
#                 {
#                     center: [37.58207472275916, 127.0554906155625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7acf6ffc71951aaff1831d768ccaf961 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7acf6ffc71951aaff1831d768ccaf961.addTo(map_b27725f37410017bf6fdff13bc60ac21);
#
#
#             var tile_layer_94ac3b883003201f7d174ba038fa7d70 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u00a9 Esri \u2014 Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_94ac3b883003201f7d174ba038fa7d70.addTo(map_b27725f37410017bf6fdff13bc60ac21);
#
#
#
#         function geo_json_56533cd437d4580ce10ef794b19fd39e_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_56533cd437d4580ce10ef794b19fd39e = L.geoJson(null, {
#                 onEachFeature: geo_json_56533cd437d4580ce10ef794b19fd39e_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_56533cd437d4580ce10ef794b19fd39e_add (data) {
#             geo_json_56533cd437d4580ce10ef794b19fd39e
#                 .addData(data);
#         }
#             geo_json_56533cd437d4580ce10ef794b19fd39e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.06757, 37.593838], [127.067399, 37.593173], [127.067433, 37.593164], [127.06823, 37.593317], [127.068098, 37.593762], [127.06786, 37.59384], [127.06757, 37.593838]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;type&quot;: &quot;park&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.051198, 37.577808], [127.051405, 37.57808], [127.05247, 37.577565], [127.051971, 37.577042], [127.050984, 37.577536], [127.051198, 37.577808]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;type&quot;: &quot;park&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.059379, 37.579219], [127.059926, 37.579572], [127.060012, 37.578924], [127.059918, 37.578873], [127.059736, 37.578864], [127.0594, 37.578783], [127.059379, 37.579219]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;type&quot;: &quot;park&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.070879, 37.57812], [127.07081, 37.577342], [127.070949, 37.577304], [127.070944, 37.576772], [127.071968, 37.576679], [127.072059, 37.578069], [127.071105, 37.578218], [127.070879, 37.57812]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;type&quot;: &quot;park&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.070209, 37.574513], [127.070067, 37.574434], [127.070086, 37.574379], [127.071086, 37.574302], [127.071102, 37.574485], [127.070209, 37.574513]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;type&quot;: &quot;park&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.073439, 37.575165], [127.073433, 37.574861], [127.074007, 37.5

# %% [markdown]
# ### **selected_area.geojson 파일 백업**

# %%
# 백업 폴더 경로
backup_dir = os.path.join(root_dir, "polygon_data")

# 백업 파일명 생성
backup_file = os.path.join(
    backup_dir, f"{target_tag}_area.geojson"
)

# geojson_data를 polygon_data에 저장
with open(backup_file, "w", encoding="utf-8") as f:
    json.dump(geojson_data, f, ensure_ascii=False, indent=2)
    
print(f"💾 geojson_data를 백업했습니다: {backup_file}")
# Out:
# 💾 geojson_data를 백업했습니다: C:\Users\rlatj\Programming_Workspace\Hanyang_Programming\Soomgil\data\polygon\polygon_data\park_area.geojson

# %% [markdown]
# ### **polygon 추가하기(필요에 따라 실행)**

# %%
file_path = "polygon_data/park_area.geojson" # *********************실행 전 확인************************

# 기존 데이터 불러오기
with open(file_path, encoding="utf-8") as f:
    original_data = json.load(f)

# Feature 합치기
merged = {
    "type": "FeatureCollection",
    "features": original_data["features"] + geojson_data["features"]
}

# 저장하기
with open("polygon_data/park_area_added.geojson", "w", encoding="utf-8") as f: # *********************실행 전 확인************************
    json.dump(merged, f, ensure_ascii=False, indent=2)
